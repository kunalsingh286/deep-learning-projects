# %% [markdown]
# # **Multi-class Classification Use Case Demonstration**
#
# Classifying data into one of multiple classes using Tensforflow/Keras

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Let's generate some synthetic data**

# %%
def generate_data(n_samples=1000, n_labels=3, random_seed=42):
    np.random.seed(random_seed)

    # Generate random 2D points
    X = np.random.randn(n_samples, 2)

    # Define label regions
    y = np.zeros((n_samples, n_labels), dtype=int)

    # Label 1: Points in the top-right quadrant
    y[:, 0] = (X[:, 0] > 0) & (X[:, 1] > 0)

    # Label 2: Points in the bottom-right quadrant
    y[:, 1] = (X[:, 0] > 0) & (X[:, 1] < 0)

    # Label 3: Points in the left half (both quadrants)
    y[:, 2] = X[:, 0] < 0

    return X, y

# Generate data
X, y = generate_data(n_samples=1000)

# Plot the data
plt.figure(figsize=(8, 6))
colors = ['r', 'g', 'b']
classes = ['Top-right', 'Bottom-right', 'Left']

for i in range(y.shape[1]):
    plt.scatter(X[y[:, i] == 1][:, 0], X[y[:, i] == 1][:, 1], alpha=0.5, label=classes[i], c=colors[i])

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Multi-Class Classification')
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.legend()
plt.show()

# %% [markdown]
# **Let's build the Neural Network Model to perform Multi-class classification**

# %%
# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(2,)),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')  # Use softmax for multi-class classification
])

# Compile the model (we use cross-entropy loss function)
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# **Let's train the neural network**

# %%
# Train the model
history = model.fit(X, y, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate the model
loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"Model Loss: {loss:.4f}")
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8587 - loss: 0.8791 - val_accuracy: 0.9550 - val_loss: 0.6888
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9700 - loss: 0.5373 - val_accuracy: 0.9800 - val_loss: 0.4086
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9675 - loss: 0.3188 - val_accuracy: 0.9800 - val_loss: 0.2563
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9650 - loss: 0.2126 - val_accuracy: 0.9900 - val_loss: 0.1785
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9700 - loss: 0.1635 - val_accuracy: 0.9800 - val_loss: 0.1434
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9650 - loss: 0.1351 - val_accuracy: 0.9850 - val_loss: 0.1202
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9725 - loss: 0.1159 - val_accuracy: 0.9850 - val_loss: 0.1027
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9762 - loss: 0.1022 - val_accuracy: 0.9850 - val_loss: 0.0930
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9737 - loss: 0.0950 - val_accuracy: 0.9800 - val_loss: 0.0838
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9737 - loss: 0.0872 - val_accuracy: 0.9800 - val_loss: 0.0796
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 0.0783 - val_accuracy: 0.9900 - val_loss: 0.0713
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9775 - loss: 0.0755 - val_accuracy: 0.9850 - val_loss: 0.0707
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.0715 - val_accuracy: 0.9950 - val_loss: 0.0657
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.0646 - val_accuracy: 0.9850 - val_loss: 0.0649
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0617 - val_accuracy: 0.9800 - val_loss: 0.0576
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9825 - loss: 0.0596 - val_accuracy: 0.9950 - val_loss: 0.0523
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9875 - loss: 0.0560 - val_accuracy: 0.9850 - val_loss: 0.0536
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9862 - loss: 0.0534 - val_accuracy: 0.9900 - val_loss: 0.0521
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9887 - loss: 0.0504 - val_accuracy: 1.0000 - val_loss: 0.0483
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9937 - loss: 0.0484 - val_accuracy: 0.9900 - val_loss: 0.0513
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9875 - loss: 0.0475 - val_accuracy: 1.0000 - val_loss: 0.0459
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9937 - loss: 0.0457 - val_accuracy: 0.9950 - val_loss: 0.0433
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9875 - loss: 0.0441 - val_accuracy: 0.9950 - val_loss: 0.0413
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9937 - loss: 0.0427 - val_accuracy: 0.9900 - val_loss: 0.0425
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9912 - loss: 0.0400 - val_accuracy: 0.9950 - val_loss: 0.0455
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9937 - loss: 0.0396 - val_accuracy: 0.9950 - val_loss: 0.0369
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9925 - loss: 0.0375 - val_accuracy: 1.0000 - val_loss: 0.0394
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0370 - val_accuracy: 1.0000 - val_loss: 0.0327
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0362 - val_accuracy: 0.9900 - val_loss: 0.0401
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0352 - val_accuracy: 0.9950 - val_loss: 0.0332
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0349 - val_accuracy: 0.9950 - val_loss: 0.0344
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0314 - val_accuracy: 1.0000 - val_loss: 0.0291
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0312
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 0.0273
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0291 - val_accuracy: 0.9900 - val_loss: 0.0293
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0309 - val_accuracy: 0.9950 - val_loss: 0.0316
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0291 - val_accuracy: 0.9950 - val_loss: 0.0304
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0263 - val_accuracy: 0.9950 - val_loss: 0.0278
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0238
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0246 - val_accuracy: 0.9950 - val_loss: 0.0282
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0246 - val_accuracy: 1.0000 - val_loss: 0.0239
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0255
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0246 - val_accuracy: 0.9950 - val_loss: 0.0297
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0232 - val_accuracy: 1.0000 - val_loss: 0.0220
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0228 - val_accuracy: 0.9950 - val_loss: 0.0256
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0217 - val_accuracy: 0.9950 - val_loss: 0.0239
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9962 - loss: 0.0225 - val_accuracy: 0.9950 - val_loss: 0.0233
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0181
# Model Loss: 0.0186
# Model Accuracy: 100.00%

# %% [markdown]
# **Let's make some predictions**

# %%
# Perform inference on the data
X = np.array([[-2, -1], [-1, -1], [2, -1], [1, 1], [1, -3], [0, 0], [-2, 2], [-4, 4], [2, 3], [2, 1]])


y_pred = model.predict(X)
y_pred_classes = (y_pred > 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step

# %% [markdown]
# **Let's plot our predictions**
#
# If our neural network is predicting correctly then it should color the dots correctly based on the quadrant they appear in

# %%
# Plot the predicted data
plt.figure(figsize=(8, 6))

for i in range(y_pred_classes.shape[1]):
    plt.scatter(X[y_pred_classes[:, i] == 1][:, 0], X[y_pred_classes[:, i] == 1][:, 1], alpha=0.5, label=f'Predicted {classes[i]}', c=colors[i])

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Predicted Multi-Label Data (2D)')
plt.legend()
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.show()
